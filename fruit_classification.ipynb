# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/fruit_classification - Sheet1.csv')

# %%
df
# Out:
#     WEIGHT(grams)  COLOR INTENSITY(0-10)    SIZE FRUIT TYPE
# 0             150                      7   LARGE      APPLE
# 1             130                      6  MEDIUM      APPLE
# 2             180                      8   LARGE      APPLE
# 3             100                      5   SMALL      APPLE
# 4             120                      3   SMALL     BANANA
# 5             110                      4  MEDIUM     BANANA
# 6             115                      3  MEDIUM     BANANA
# 7             105                      2   SMALL     BANANA
# 8             160                      9   LARGE     ORANGE
# 9             150                      8  MEDIUM     ORANGE
# 10            155                      9   LARGE     ORANGE
# 11            140                      7  MEDIUM     ORANGE

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['SIZE']= label_encoder.fit_transform(df['SIZE'])

# %%
df.head()
# Out:
#    WEIGHT(grams)  COLOR INTENSITY(0-10)  SIZE FRUIT TYPE
# 0            150                      7     0      APPLE
# 1            130                      6     1      APPLE
# 2            180                      8     0      APPLE
# 3            100                      5     2      APPLE
# 4            120                      3     2     BANANA

# %%
X = df[['WEIGHT(grams)','SIZE','COLOR INTENSITY(0-10)']]
Y = df['FRUIT TYPE']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)

# %%
new = np.array([[140,7,1]])

y_pred = knn.predict(new)
print(y_pred)
# Out:
# ['APPLE']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
